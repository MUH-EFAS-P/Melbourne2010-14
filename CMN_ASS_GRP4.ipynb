# %%
#MELBOURNE GROUP 4

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('city_temperature all.csv', low_memory=False)
df.info()
df.head()

new_Df=df[df['City']=='Melbourne']
new_Df.info()
print(new_Df)

city_Melbourne_clean=new_Df.drop(['Region','Country','State','City'],axis=1)
print(city_Melbourne_clean.head())
print(city_Melbourne_clean.tail())
city_Melbourne_clean.info()

#2010
print("YEAR: 2010")

CT_Melbourne_Jan2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==1)]
CT_Melbourne_Feb2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==2)]
CT_Melbourne_Mar2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==3)]
CT_Melbourne_Apr2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==4)]
CT_Melbourne_May2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==5)]
CT_Melbourne_Jun2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==6)]
CT_Melbourne_Jul2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==7)]
CT_Melbourne_Aug2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==8)]
CT_Melbourne_Sep2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==9)]
CT_Melbourne_Oct2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==10)]
CT_Melbourne_Nov2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==11)]
CT_Melbourne_Dec2010=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2010)&
                                            (city_Melbourne_clean['Month']==12)]

print(CT_Melbourne_Jan2010.head())
print(CT_Melbourne_Feb2010.head())
print(CT_Melbourne_Mar2010.head())
print(CT_Melbourne_Apr2010.head())
print(CT_Melbourne_May2010.head())
print(CT_Melbourne_Jun2010.head())
print(CT_Melbourne_Jul2010.head())
print(CT_Melbourne_Aug2010.head())
print(CT_Melbourne_Sep2010.head())
print(CT_Melbourne_Oct2010.head())
print(CT_Melbourne_Nov2010.head())
print(CT_Melbourne_Dec2010.head())

#2011
print("YEAR: 2011")

CT_Melbourne_Jan2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==1)]
CT_Melbourne_Feb2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==2)]
CT_Melbourne_Mar2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==3)]
CT_Melbourne_Apr2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==4)]
CT_Melbourne_May2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==5)]
CT_Melbourne_Jun2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==6)]
CT_Melbourne_Jul2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==7)]
CT_Melbourne_Aug2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==8)]
CT_Melbourne_Sep2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==9)]
CT_Melbourne_Oct2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==10)]
CT_Melbourne_Nov2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==11)]
CT_Melbourne_Dec2011=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2011)&
                                            (city_Melbourne_clean['Month']==12)]

print(CT_Melbourne_Jan2011.head())
print(CT_Melbourne_Feb2011.head())
print(CT_Melbourne_Mar2011.head())
print(CT_Melbourne_Apr2011.head())
print(CT_Melbourne_May2011.head())
print(CT_Melbourne_Jun2011.head())
print(CT_Melbourne_Jul2011.head())
print(CT_Melbourne_Aug2011.head())
print(CT_Melbourne_Sep2011.head())
print(CT_Melbourne_Oct2011.head())
print(CT_Melbourne_Nov2011.head())
print(CT_Melbourne_Dec2011.head())


#2012
print("YEAR: 2012")

CT_Melbourne_Jan2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==1)]
CT_Melbourne_Feb2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==2)]
CT_Melbourne_Mar2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==3)]
CT_Melbourne_Apr2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==4)]
CT_Melbourne_May2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==5)]
CT_Melbourne_Jun2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==6)]
CT_Melbourne_Jul2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==7)]
CT_Melbourne_Aug2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==8)]
CT_Melbourne_Sep2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==9)]
CT_Melbourne_Oct2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==10)]
CT_Melbourne_Nov2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==11)]
CT_Melbourne_Dec2012=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2012)&
                                            (city_Melbourne_clean['Month']==12)]

print(CT_Melbourne_Jan2012.head())
print(CT_Melbourne_Feb2012.head())
print(CT_Melbourne_Mar2012.head())
print(CT_Melbourne_Apr2012.head())
print(CT_Melbourne_May2012.head())
print(CT_Melbourne_Jun2012.head())
print(CT_Melbourne_Jul2012.head())
print(CT_Melbourne_Aug2012.head())
print(CT_Melbourne_Sep2012.head())
print(CT_Melbourne_Oct2012.head())
print(CT_Melbourne_Nov2012.head())
print(CT_Melbourne_Dec2012.head())

#2013
print("YEAR: 2013")

CT_Melbourne_Jan2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==1)]
CT_Melbourne_Feb2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==2)]
CT_Melbourne_Mar2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==3)]
CT_Melbourne_Apr2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==4)]
CT_Melbourne_May2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==5)]
CT_Melbourne_Jun2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==6)]
CT_Melbourne_Jul2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==7)]
CT_Melbourne_Aug2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==8)]
CT_Melbourne_Sep2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==9)]
CT_Melbourne_Oct2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==10)]
CT_Melbourne_Nov2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==11)]
CT_Melbourne_Dec2013=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2013)&
                                            (city_Melbourne_clean['Month']==12)]

print(CT_Melbourne_Jan2013.head())
print(CT_Melbourne_Feb2013.head())
print(CT_Melbourne_Mar2013.head())
print(CT_Melbourne_Apr2013.head())
print(CT_Melbourne_May2013.head())
print(CT_Melbourne_Jun2013.head())
print(CT_Melbourne_Jul2013.head())
print(CT_Melbourne_Aug2013.head())
print(CT_Melbourne_Sep2013.head())
print(CT_Melbourne_Oct2013.head())
print(CT_Melbourne_Nov2013.head())
print(CT_Melbourne_Dec2013.head())


#2014
print("YEAR: 2014")

CT_Melbourne_Jan2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==1)]
CT_Melbourne_Feb2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==2)]
CT_Melbourne_Mar2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==3)]
CT_Melbourne_Apr2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==4)]
CT_Melbourne_May2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==5)]
CT_Melbourne_Jun2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==6)]
CT_Melbourne_Jul2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==7)]
CT_Melbourne_Aug2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==8)]
CT_Melbourne_Sep2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==9)]
CT_Melbourne_Oct2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==10)]
CT_Melbourne_Nov2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==11)]
CT_Melbourne_Dec2014=city_Melbourne_clean.loc[(city_Melbourne_clean['Year']==2014)&
                                            (city_Melbourne_clean['Month']==12)]

print(CT_Melbourne_Jan2014.head())
print(CT_Melbourne_Feb2014.head())
print(CT_Melbourne_Mar2014.head())
print(CT_Melbourne_Apr2014.head())
print(CT_Melbourne_May2014.head())
print(CT_Melbourne_Jun2014.head())
print(CT_Melbourne_Jul2014.head())
print(CT_Melbourne_Aug2014.head())
print(CT_Melbourne_Sep2014.head())
print(CT_Melbourne_Oct2014.head())
print(CT_Melbourne_Nov2014.head())
print(CT_Melbourne_Dec2014.head())

#Melbourne City Avg Monthly Temperature

jan_Melbourne=np.empty(5)
feb_Melbourne=np.empty(5)
mar_Melbourne=np.empty(5)
apr_Melbourne=np.empty(5)
may_Melbourne=np.empty(5)
jun_Melbourne=np.empty(5)
jul_Melbourne=np.empty(5)
aug_Melbourne=np.empty(5)
sep_Melbourne=np.empty(5)
oct_Melbourne=np.empty(5)
nov_Melbourne=np.empty(5)
dec_Melbourne=np.empty(5)


#
jan_Melbourne[0]=round(CT_Melbourne_Jan2010['AvgTemperature'].mean(),2)
jan_Melbourne[1]=round(CT_Melbourne_Jan2011['AvgTemperature'].mean(),2)
jan_Melbourne[2]=round(CT_Melbourne_Jan2012['AvgTemperature'].mean(),2)
jan_Melbourne[3]=round(CT_Melbourne_Jan2013['AvgTemperature'].mean(),2)
jan_Melbourne[4]=round(CT_Melbourne_Jan2014['AvgTemperature'].mean(),2)

feb_Melbourne[0]=round(CT_Melbourne_Feb2010['AvgTemperature'].mean(),2)
feb_Melbourne[1]=round(CT_Melbourne_Feb2011['AvgTemperature'].mean(),2)
feb_Melbourne[2]=round(CT_Melbourne_Feb2012['AvgTemperature'].mean(),2)
feb_Melbourne[3]=round(CT_Melbourne_Feb2013['AvgTemperature'].mean(),2)
feb_Melbourne[4]=round(CT_Melbourne_Feb2014['AvgTemperature'].mean(),2)

mar_Melbourne[0]=round(CT_Melbourne_Mar2010['AvgTemperature'].mean(),2)
mar_Melbourne[1]=round(CT_Melbourne_Mar2011['AvgTemperature'].mean(),2)
mar_Melbourne[2]=round(CT_Melbourne_Mar2012['AvgTemperature'].mean(),2)
mar_Melbourne[3]=round(CT_Melbourne_Mar2013['AvgTemperature'].mean(),2)
mar_Melbourne[4]=round(CT_Melbourne_Mar2014['AvgTemperature'].mean(),2)

apr_Melbourne[0]=round(CT_Melbourne_Apr2010['AvgTemperature'].mean(),2)
apr_Melbourne[1]=round(CT_Melbourne_Apr2011['AvgTemperature'].mean(),2)
apr_Melbourne[2]=round(CT_Melbourne_Apr2012['AvgTemperature'].mean(),2)
apr_Melbourne[3]=round(CT_Melbourne_Apr2013['AvgTemperature'].mean(),2)
apr_Melbourne[4]=round(CT_Melbourne_Apr2014['AvgTemperature'].mean(),2)

may_Melbourne[0]=round(CT_Melbourne_May2010['AvgTemperature'].mean(),2)
may_Melbourne[1]=round(CT_Melbourne_May2011['AvgTemperature'].mean(),2)
may_Melbourne[2]=round(CT_Melbourne_May2012['AvgTemperature'].mean(),2)
may_Melbourne[3]=round(CT_Melbourne_May2013['AvgTemperature'].mean(),2)
may_Melbourne[4]=round(CT_Melbourne_May2014['AvgTemperature'].mean(),2)

jun_Melbourne[0]=round(CT_Melbourne_Jun2010['AvgTemperature'].mean(),2)
jun_Melbourne[1]=round(CT_Melbourne_Jun2011['AvgTemperature'].mean(),2)
jun_Melbourne[2]=round(CT_Melbourne_Jun2012['AvgTemperature'].mean(),2)
jun_Melbourne[3]=round(CT_Melbourne_Jun2013['AvgTemperature'].mean(),2)
jun_Melbourne[4]=round(CT_Melbourne_Jun2014['AvgTemperature'].mean(),2)

jul_Melbourne[0]=round(CT_Melbourne_Jul2010['AvgTemperature'].mean(),2)
jul_Melbourne[1]=round(CT_Melbourne_Jul2011['AvgTemperature'].mean(),2)
jul_Melbourne[2]=round(CT_Melbourne_Jul2012['AvgTemperature'].mean(),2)
jul_Melbourne[3]=round(CT_Melbourne_Jul2013['AvgTemperature'].mean(),2)
jul_Melbourne[4]=round(CT_Melbourne_Jul2014['AvgTemperature'].mean(),2)

aug_Melbourne[0]=round(CT_Melbourne_Aug2010['AvgTemperature'].mean(),2)
aug_Melbourne[1]=round(CT_Melbourne_Aug2011['AvgTemperature'].mean(),2)
aug_Melbourne[2]=round(CT_Melbourne_Aug2012['AvgTemperature'].mean(),2)
aug_Melbourne[3]=round(CT_Melbourne_Aug2013['AvgTemperature'].mean(),2)
aug_Melbourne[4]=round(CT_Melbourne_Aug2014['AvgTemperature'].mean(),2)

sep_Melbourne[0]=round(CT_Melbourne_Sep2010['AvgTemperature'].mean(),2)
sep_Melbourne[1]=round(CT_Melbourne_Sep2011['AvgTemperature'].mean(),2)
sep_Melbourne[2]=round(CT_Melbourne_Sep2012['AvgTemperature'].mean(),2)
sep_Melbourne[3]=round(CT_Melbourne_Sep2013['AvgTemperature'].mean(),2)
sep_Melbourne[4]=round(CT_Melbourne_Sep2014['AvgTemperature'].mean(),2)

oct_Melbourne[0]=round(CT_Melbourne_Oct2010['AvgTemperature'].mean(),2)
oct_Melbourne[1]=round(CT_Melbourne_Oct2011['AvgTemperature'].mean(),2)
oct_Melbourne[2]=round(CT_Melbourne_Oct2012['AvgTemperature'].mean(),2)
oct_Melbourne[3]=round(CT_Melbourne_Oct2013['AvgTemperature'].mean(),2)
oct_Melbourne[4]=round(CT_Melbourne_Oct2014['AvgTemperature'].mean(),2)

nov_Melbourne[0]=round(CT_Melbourne_Nov2010['AvgTemperature'].mean(),2)
nov_Melbourne[1]=round(CT_Melbourne_Nov2011['AvgTemperature'].mean(),2)
nov_Melbourne[2]=round(CT_Melbourne_Nov2012['AvgTemperature'].mean(),2)
nov_Melbourne[3]=round(CT_Melbourne_Nov2013['AvgTemperature'].mean(),2)
nov_Melbourne[4]=round(CT_Melbourne_Nov2014['AvgTemperature'].mean(),2)

dec_Melbourne[0]=round(CT_Melbourne_Dec2010['AvgTemperature'].mean(),2)
dec_Melbourne[1]=round(CT_Melbourne_Dec2011['AvgTemperature'].mean(),2)
dec_Melbourne[2]=round(CT_Melbourne_Dec2012['AvgTemperature'].mean(),2)
dec_Melbourne[3]=round(CT_Melbourne_Dec2013['AvgTemperature'].mean(),2)
dec_Melbourne[4]=round(CT_Melbourne_Dec2014['AvgTemperature'].mean(),2)

AVTemp_MelbourneDF=pd.DataFrame({'JAN':jan_Melbourne,
                                'FEB':feb_Melbourne,
                                'MAR':mar_Melbourne,
                                'APR':apr_Melbourne,
                                'MAY':may_Melbourne,
                                'JUN':jun_Melbourne,
                                'JUL':jul_Melbourne,
                                'AUG':aug_Melbourne,
                                'SEP':sep_Melbourne,
                                'OCT':oct_Melbourne,
                                'NOV':nov_Melbourne,
                                'DEC':dec_Melbourne,
                                'Year':[2010,2011,2012,2013,2014]})
print(" ")
print(AVTemp_MelbourneDF)

#BAR-PLOT

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='JAN',color='red',
                       title='Melbourne city Average January Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='FEB',color='green',
                       title='Melbourne city Average February Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='MAR',color='blue',
                       title='Melbourne city Average MARCH Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='APR',color='orange',
                       title='Melbourne city Average APRIL Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='MAY',color='violet',
                       title='Melbourne city Average MAY Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='JUN',color='yellow',
                       title='Melbourne city Average JUNE Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='JUL',color='cyan',
                       title='Melbourne city Average JULY Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='AUG',color='black',
                       title='Melbourne city Average AUGUST Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='SEP',color='magenta',
                       title='Melbourne city Average SEPTEMBER Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='OCT',color='pink',
                       title='Melbourne city Average OCTOBER Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='NOV',color='olive',
                       title='Melbourne city Average NOVEMBER Temperature')

AVTemp_MelbourneDF.plot(kind='bar',x="Year",y='DEC',color='darkviolet',
                       title='Melbourne city Average DECEMBER Temperature')

##
AVTemp_MelbourneDF.plot(kind='line',x="Year",color=['red','green','blue','orange','maroon','yellow','cyan','black','magenta','mediumblue','olive','darkviolet'],
                       title='Melbourne city Average Temperature')
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.grid()

AVTemp_MelbourneDF.plot(kind='bar',x="Year",color=['red','green','blue','orange','maroon','yellow','cyan','black','magenta','mediumblue','olive','darkviolet'],
                       title='Melbourne city Average Temperature')
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))

#ANALYSIS

melb_temp=pd.DataFrame({'JAN':jan_Melbourne,
                                'FEB':feb_Melbourne,
                                'MAR':mar_Melbourne,
                                'APR':apr_Melbourne,
                                'MAY':may_Melbourne,
                                'JUN':jun_Melbourne,
                                'JUL':jul_Melbourne,
                                'AUG':aug_Melbourne,
                                'SEP':sep_Melbourne,
                                'OCT':oct_Melbourne,
                                'NOV':nov_Melbourne,
                                'DEC':dec_Melbourne
             })

max_melbTemp=melb_temp.max().max()
max_melbTempMonth=melb_temp.stack().idxmax()
min_melbTemp=melb_temp.min().min()
min_melbTempMonth=melb_temp.stack().idxmin()

#print(max_melbTempMonth)
#print(min_melbTempMonth)

print('MAXIMUM TEMPERATURE EXPERIENCED OVER THE YEAR 2010-14 WAS: ',max_melbTemp, 'Fahrenheit ON')
if max_melbTempMonth[0]==0:
    print(max_melbTempMonth[1],'OF THE YEAR 2010  ')
elif max_melbTempMonth[0]==1:
    print(max_melbTempMonth[1],'OF THE YEAR 2011  ')
elif max_melbTempMonth[0]==2:
    print(max_melbTempMonth[1],'OF THE YEAR 2012  ')
elif max_melbTempMonth[0]==3:
    print(max_melbTempMonth[1],'OF THE YEAR 2013  ')
else:
    print(max_melbTempMonth[1],'OF THE YEAR 2014  ')

print("\n")    
    
print('MINIMUM TEMPERATURE EXPERIENCED OVER THE YEAR 2010-14 WAS: :',min_melbTemp, 'Fahrenheit ON')   
if min_melbTempMonth[0]==0:
    print(min_melbTempMonth[1],'OF THE YEAR 2010  ')
elif min_melbTempMonth[0]==1:
    print(min_melbTempMonth[1],'OF THE YEAR 2011  ')
elif min_melbTempMonth[0]==2:
    print(min_melbTempMonth[1],'OF THE YEAR 2012  ')
elif min_melbTempMonth[0]==3:
    print(min_melbTempMonth[1],'OF THE YEAR 2013  ')
elif min_melbTempMonth[0]==4:
    print(min_melbTempMonth[1],'OF THE YEAR 2014  ')
    
    
#YEAR 2010 VS 2014
print('\n','YEAR 2010')

year2010=melb_temp.loc[0]
y2010=year2010.values
print(y2010)

print('\n','YEAR 2014')

year2014=melb_temp.loc[4]
y2014=year2014.values
print(y2014)

print(" ")

print("SEASONAL ANALYSIS: ")

summer10=np.empty(3)#dec jan feb
autumn10=np.empty(3)#mar apr may
winter10=np.empty(3)#jun jul aug
spring10=np.empty(3)#sep oct nov

summer14=np.empty(3)#dec jan feb
autumn14=np.empty(3)#mar apr may
winter14=np.empty(3)#jun jul aug
spring14=np.empty(3)#sep oct nov

#summer

summer10[0]=dec_Melbourne[0]
summer10[1]=jan_Melbourne[0]
summer10[2]=feb_Melbourne[0]

summer14[0]=dec_Melbourne[4]
summer14[1]=jan_Melbourne[4]
summer14[2]=feb_Melbourne[4]

#autumn

autumn10[0]=mar_Melbourne[0]
autumn10[1]=apr_Melbourne[0]
autumn10[2]=may_Melbourne[0]

autumn14[0]=mar_Melbourne[4]
autumn14[1]=apr_Melbourne[4]
autumn14[2]=may_Melbourne[4]

#winter

winter10[0]=jun_Melbourne[0]
winter10[1]=jul_Melbourne[0]
winter10[2]=aug_Melbourne[0]

winter14[0]=jun_Melbourne[4]
winter14[1]=jul_Melbourne[4]
winter14[2]=aug_Melbourne[4]

#spring

spring10[0]=sep_Melbourne[0]
spring10[1]=oct_Melbourne[0]
spring10[2]=nov_Melbourne[0]

spring14[0]=sep_Melbourne[4]
spring14[1]=oct_Melbourne[4]
spring14[2]=nov_Melbourne[4]

print("AVG TEMP. SUMMER 2010: ",round(summer10.mean(),2))
print("AVG TEMP. SUMMER 2014: ",round(summer14.mean(),2))
print("AVG TEMP. AUTUMN 2010: ",round(autumn10.mean(),2))
print("AVG TEMP. AUTUMN 2014: ",round(autumn14.mean(),2))
print("AVG TEMP. WINTER 2010: ",round(winter10.mean(),2))
print("AVG TEMP. WINTER 2014: ",round(winter14.mean(),2))
print("AVG TEMP. SPRING 2010: ",round(spring10.mean(),2))
print("AVG TEMP. SPRING 2014: ",round(spring14.mean(),2))

s10=round(summer10.mean(),2)
s14=round(summer14.mean(),2)
a10=round(autumn10.mean(),2)
a14=round(autumn14.mean(),2)
w10=round(winter10.mean(),2)
w14=round(winter14.mean(),2)
sp10=round(spring10.mean(),2)
sp14=round(spring14.mean(),2)

print("")

if s10>s14:
    print("SUMMER 2010 was hotter than 2014 with a temperature difference of: ",round(s10-s14,2))
else:
    print("SUMMER 2014 was hotter than 2010 with a temperature difference of: ",round(s14-s10,2))
    
if a10>a14:
    print("AUTUMN 2010 was hotter than 2014 with a temperature difference of: ",round(a10-a14,2))
else:
    print("AUTUMN 2014 was hotter than 2010 with a temperature difference of: ",round(a14-a10,2))
    
if w10>w14:
    print("WINTER 2014 was colder than 2010 with a temperature difference of: ",round(w10-w14,2))
else:
    print("WINTER 2010 was colder than 2014 with a temperature difference of: ",round(w14-w10,2))
    
if sp10>sp14:
    print("SPRING 2010 was hotter than 2014 with a temperature difference of: ",round(sp10-sp14,2))
else:
    print("SPRING 2014 was hotter than 2010 with a temperature difference of: ",round(sp14-sp10,2))

    
Avg_Temp_Rise=
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   State           object
#  3   City            object
#  4   Month           int64
#  5   Day             int64
#  6   Year            int64
#  7   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 177.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9266 entries, 586313 to 595578
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          9266 non-null   object
#  1   Country         9266 non-null   object
#  2   State           0 non-null      object
#  3   City            9266 non-null   object
#  4   Month           9266 non-null   int64
#  5   Day             9266 non-null   int64
# ...
